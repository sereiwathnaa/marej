# %%
from transformers import LlamaModel

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Model name for Llama 2 7B
model_name = "meta-llama/Llama-2-7b-hf"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    dtype=torch.float16,  # Use float16 to reduce memory usage
    device_map="auto",          # Automatically map to available devices (GPU/CPU)
    use_auth_token=True         # Required to access Meta's models
)

# Example usage
prompt = "Explain the importance of open source software in AI development."
inputs = tokenizer(prompt, return_tensors="pt")

# # Generate text
# with torch.no_grad():
#     outputs = model.generate(
#         inputs.input_ids,
#         max_length=200,
#         temperature=0.7,
#         do_sample=True,
#         pad_token_id=tokenizer.eos_token_id
#     )

# # Decode the generated text
# generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
# print(generated_text)

# %%
model.model.layers

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    dtype=torch.float16,  # Use float16 to reduce memory usage
    device_map="auto",          # Automatically map to available devices (GPU/CPU)
    use_auth_token=True         # Required to access Meta's models
)

# %%
with torch.no_grad():
    outputs = model.generate(
        inputs.input_ids,
        max_length=20,
        temperature=0.7,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id
    )

# Decode the generated text
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(generated_text)

# %%
model.model

# %%
model.model.embed_tokens.weight

# %%
model.model.embed

# %%
model.model.layers[0].self_attn.q_proj.weight

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from model import Llama
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from model import Llama
#
# File ~/my_project/marejv2/src/models/llama/model.py:146
#     133 model = Llama(
#     134     n_layers=6,
#     135     n_heads=32,
#    (...)    141     use_flash=True
#     142 ).cuda()
#     144 x = torch.randn(1, 32, 4096)
# --> 146 y = model(x)
#
# File ~/anaconda3/envs/gen/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/gen/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/my_project/marejv2/src/models/llama/model.py:117, in Llama.forward(self, indices, use_kv_cache)
#     114 def forward(self,
#     115             indices: Tensor,
#     116             use_kv_cache: bool=False):
# --> 117     x = self.word_embeddings(indices)
#     118     for decoder_block in self.decoder_blocks:
#     119         x = decoder_block(x, use_kv_cache, self.rotation_matr)
#
# File ~/anaconda3/envs/gen/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/gen/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/gen/lib/python3.11/site-packages/torch/nn/modules/sparse.py:192, in Embedding.forward(self, input)
#     191 def forward(self, input: Tensor) -> Tensor:
# --> 192     return F.embedding(
#     193         input,
#     194         self.weight,
#     195         self.padding_idx,
#     196         self.max_norm,
#     197         self.norm_type,
#     198         self.scale_grad_by_freq,
#     199         self.sparse,
#     200     )
#
# File ~/anaconda3/envs/gen/lib/python3.11/site-packages/torch/nn/functional.py:2546, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2540     # Note [embedding_renorm set_grad_enabled]
#    2541     # XXX: equivalent to
#    2542     # with torch.no_grad():
#    2543     #   torch.embedding_renorm_
#    2544     # remove once script supports set_grad_enabled
#    2545     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2546 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: Expected tensor for argument #1 'indices' to have one of the following scalar types: Long, Int; but got torch.FloatTensor instead (while checking arguments for embedding)

# %%
model = Llama(
    n_layers=32,
    n_heads=32,
    embed_dim=4096,
    vocab_size=32000,
    block_size=2048,
    n_kv_heads=None,
    ffn_hidden_dim=None,
    use_flash=True
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model
# Out:
# Llama(
#   (word_embeddings): Embedding(32000, 4096)
#   (decoder_blocks): ModuleList(
#     (0): DecoderBlock(
#       (norm1): RMSNorm()
#       (attn): GroupedQueryRotaryAttention(embed_dim=4096, n_heads=32, n_kv_heads=32, apply_rotary_embedding=True)
#       (norm2): RMSNorm()
#       (ffn): FeedForwardBlock(
#         (linear1): Linear(in_features=4096, out_features=11008, bias=False)
#         (linear2): Linear(in_features=11008, out_features=4096, bias=False)
#         (linear3): Linear(in_features=4096, out_features=11008, bias=False)
#       )
#     )
#   )
#   (rms_norm): RMSNorm()
#   (output_projection): Linear(in_features=4096, out_features=32000, bias=False)
# )
